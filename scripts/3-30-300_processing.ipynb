# %%
import sys, re, json
sys.path.append('..') 

from scripts.constants import *
from scripts.utils import *
from scripts.sedona_config import *

import pandas as pd
import geopandas as gpd
from tqdm import tqdm

# %%
T3_30_300_DIR = VECTOR_OUT_DIR / "3-30-300"
T3_dir = T3_30_300_DIR / "T3"
T30_dir = T3_30_300_DIR / "T30"
T300_dir = T3_30_300_DIR / "T300"
imd_lsoa_bua_boundaries_path = VECTOR_OUT_DIR / "IMD" / "English_IMD_2019_BUA_filtered_boundaries.geojson"
imd_england_path = VECTOR_IN_DIR / "IMD" / "English IMD 2019" / "IMD_2019.shp"
buildings_path = VECTOR_IN_DIR / "EDINA" / "Buildings_6183" / "Buildings_6183.parquet"

# %%
geo_level = 'LAD22CD'
geo_code = 'E07000008'
imd_lsoa_bua_gdf = gpd.read_file(imd_lsoa_bua_boundaries_path)
geo_level_codes = imd_lsoa_bua_gdf[geo_level].unique()
imd_england_columns = ['lsoa11cd', 'TotPop', 'DepChi', 'Pop16_59', 'Pop60+', 'WorkPop',
                       'IMD_Rank', 'IMD_Decile', 'IMDScore', 'IncScore', 'IncRank', 'IncDec', 
                       'EmpScore', 'EmpRank', 'EmpDec', 'EduScore', 'EduRank', 'EduDec', 
                       'HDDScore', 'HDDRank', 'HDDDec', 'CriScore', 'CriRank', 'CriDec', 
                       'BHSScore', 'BHSRank', 'BHSDec', 'EnvScore', 'EnvRank', 'EnvDec']
imd_england_gdf = gpd.read_file(imd_england_path)[imd_england_columns]

# %%
imd_lsoa_bua_gdf.to_file(VECTOR_OUT_DIR / "IMD" / "English_IMD_2019_BUA_filtered_boundaries.shp")
# Out:
# ---------------------------------------------------------------------------
# CPLE_AppDefinedError                      Traceback (most recent call last)
# File pyogrio/_io.pyx:2193, in pyogrio._io.create_ogr_dataset_layer()
#
# File pyogrio/_err.pyx:183, in pyogrio._err.exc_wrap_pointer()
#
# CPLE_AppDefinedError: Failed to create file /maps/acz25/phd-thesis-data/output/vector/IMD/English_IMD_2019_BUA_filtered_boundaries.shp: No space left on device
#
# During handling of the above exception, another exception occurred:
#
# DataLayerError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 imd_lsoa_bua_gdf.to_file(VECTOR_OUT_DIR / "IMD" / "English_IMD_2019_BUA_filtered_boundaries.shp")
#
# File /maps/acz25/miniconda3/envs/3-30-300-env/lib/python3.10/site-packages/geopandas/geodataframe.py:1536, in GeoDataFrame.to_file(self, filename, driver, schema, index, **kwargs)
#    1441 """Write the ``GeoDataFrame`` to a file.
#    1442
#    1443 By default, an ESRI shapefile is written, but any OGR data source
#    (...)
#    1532
#    1533 """
#    1534 from geopandas.io.file import _to_file
# -> 1536 _to_file(self, filename, driver, schema, index, **kwargs)
#
# File /maps/acz25/miniconda3/envs/3-30-300-env/lib/python3.10/site-packages/geopandas/io/file.py:686, in _to_file(df, filename, driver, schema, index, mode, crs, engine, metadata, **kwargs)
#     683     raise ValueError(f"'mode' should be one of 'w' or 'a', got '{mode}' instead")
#     685 if engine == "pyogrio":
# --> 686     _to_file_pyogrio(df, filename, driver, schema, crs, mode, metadata, **kwargs)
#     687 elif engine == "fiona":
#     688     _to_file_fiona(df, filename, driver, schema, crs, mode, metadata, **kwargs)
#
# File /maps/acz25/miniconda3/envs/3-30-300-env/lib/python3.10/site-packages/geopandas/io/file.py:748, in _to_file_pyogrio(df, filename, driver, schema, crs, mode, metadata, **kwargs)
#     745 if not df.columns.is_unique:
#     746     raise ValueError("GeoDataFrame cannot contain duplicated column names.")
# --> 748 pyogrio.write_dataframe(df, filename, driver=driver, metadata=metadata, **kwargs)
#
# File /maps/acz25/miniconda3/envs/3-30-300-env/lib/python3.10/site-packages/pyogrio/geopandas.py:662, in write_dataframe(df, path, layer, driver, encoding, geometry_type, promote_to_multi, nan_as_null, append, use_arrow, dataset_metadata, layer_metadata, metadata, dataset_options, layer_options, **kwargs)
#     659 if geometry_column is not None:
#     660     geometry = to_wkb(geometry.values)
# --> 662 write(
#     663     path,
#     664     layer=layer,
#     665     driver=driver,
#     666     geometry=geometry,
#     667     field_data=field_data,
#     668     field_mask=field_mask,
#     669     fields=fields,
#     670     crs=crs,
#     671     geometry_type=geometry_type,
#     672     encoding=encoding,
#     673     promote_to_multi=promote_to_multi,
#     674     nan_as_null=nan_as_null,
#     675     append=append,
#     676     dataset_metadata=dataset_metadata,
#     677     layer_metadata=layer_metadata,
#     678     metadata=metadata,
#     679     dataset_options=dataset_options,
#     680     layer_options=layer_options,
#     681     gdal_tz_offsets=gdal_tz_offsets,
#     682     **kwargs,
#     683 )
#
# File /maps/acz25/miniconda3/envs/3-30-300-env/lib/python3.10/site-packages/pyogrio/raw.py:723, in write(path, geometry, field_data, fields, field_mask, layer, driver, geometry_type, crs, encoding, promote_to_multi, nan_as_null, append, dataset_metadata, layer_metadata, metadata, dataset_options, layer_options, gdal_tz_offsets, **kwargs)
#     718 # preprocess kwargs and split in dataset and layer creation options
#     719 dataset_kwargs, layer_kwargs = _preprocess_options_kwargs(
#     720     driver, dataset_options, layer_options, kwargs
#     721 )
# --> 723 ogr_write(
#     724     path,
#     725     layer=layer,
#     726     driver=driver,
#     727     geometry=geometry,
#     728     geometry_type=geometry_type,
#     729     field_data=field_data,
#     730     field_mask=field_mask,
#     731     fields=fields,
#     732     crs=crs,
#     733     encoding=encoding,
#     734     promote_to_multi=promote_to_multi,
#     735     nan_as_null=nan_as_null,
#     736     append=append,
#     737     dataset_metadata=dataset_metadata,
#     738     layer_metadata=layer_metadata,
#     739     dataset_kwargs=dataset_kwargs,
#     740     layer_kwargs=layer_kwargs,
#     741     gdal_tz_offsets=gdal_tz_offsets,
#     742 )
#
# File pyogrio/_io.pyx:2307, in pyogrio._io.ogr_write()
#
# File pyogrio/_io.pyx:2207, in pyogrio._io.create_ogr_dataset_layer()
#
# DataLayerError: Failed to create file /maps/acz25/phd-thesis-data/output/vector/IMD/English_IMD_2019_BUA_filtered_boundaries.shp: No space left on device

# %%
os.environ["JAVA_HOME"] = JAVA_HOME
sedona = get_spark()
# Out:
# 24/12/11 09:43:51 WARN Utils: Your hostname, kinabalu resolves to a loopback address: 127.0.1.1; using 128.232.93.1 instead (on interface eno12399np0)
# 24/12/11 09:43:51 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# https://artifacts.unidata.ucar.edu/repository/unidata-all added as a remote repository with the name: repo-1
# Ivy Default Cache set to: /home/acz25/.ivy2/cache
# The jars for the packages stored in: /home/acz25/.ivy2/jars
# org.apache.sedona#sedona-spark-3.5_2.12 added as a dependency
# org.datasyslab#geotools-wrapper added as a dependency
# net.postgis#postgis-jdbc added as a dependency
# net.postgis#postgis-geometry added as a dependency
# org.postgresql#postgresql added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-ca804951-816e-4851-b0a0-20634a08ab36;1.0
# 	confs: [default]
# 	found org.apache.sedona#sedona-spark-3.5_2.12;1.7.0 in central
# :: loading settings :: url = jar:file:/maps-priv/maps/acz25/miniconda3/envs/3-30-300-env/lib/python3.10/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# 	found org.apache.sedona#sedona-common;1.7.0 in central
# 	found org.apache.commons#commons-math3;3.6.1 in central
# 	found org.locationtech.jts#jts-core;1.20.0 in central
# 	found org.wololo#jts2geojson;0.16.1 in central
# 	found org.locationtech.spatial4j#spatial4j;0.8 in central
# 	found com.google.geometry#s2-geometry;2.0.0 in central
# 	found com.google.guava#guava;25.1-jre in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found org.checkerframework#checker-qual;2.0.0 in central
# 	found com.google.errorprone#error_prone_annotations;2.1.3 in central
# 	found com.google.j2objc#j2objc-annotations;1.1 in central
# 	found org.codehaus.mojo#animal-sniffer-annotations;1.14 in central
# 	found com.uber#h3;4.1.1 in central
# 	found net.sf.geographiclib#GeographicLib-Java;1.52 in central
# 	found com.github.ben-manes.caffeine#caffeine;2.9.2 in central
# 	found org.checkerframework#checker-qual;3.10.0 in central
# 	found com.google.errorprone#error_prone_annotations;2.5.1 in central
# 	found org.apache.sedona#sedona-spark-common-3.5_2.12;1.7.0 in central
# 	found org.xerial#sqlite-jdbc;3.41.2.2 in central
# 	found commons-lang#commons-lang;2.6 in central
# 	found graphframes#graphframes;0.8.3-spark3.5-s_2.12 in spark-packages
# 	found org.slf4j#slf4j-api;1.7.36 in central
# 	found org.scala-lang.modules#scala-collection-compat_2.12;2.5.0 in central
# 	found org.beryx#awt-color-factory;1.0.0 in central
# 	found org.datasyslab#geotools-wrapper;1.7.0-28.5 in central
# 	found net.postgis#postgis-jdbc;2021.1.0 in central
# 	found net.postgis#postgis-geometry;2021.1.0 in central
# 	found org.postgresql#postgresql;42.5.4 in central
# :: resolution report :: resolve 447ms :: artifacts dl 15ms
# 	:: modules in use:
# 	com.github.ben-manes.caffeine#caffeine;2.9.2 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.errorprone#error_prone_annotations;2.5.1 from central in [default]
# 	com.google.geometry#s2-geometry;2.0.0 from central in [default]
# 	com.google.guava#guava;25.1-jre from central in [default]
# 	com.google.j2objc#j2objc-annotations;1.1 from central in [default]
# 	com.uber#h3;4.1.1 from central in [default]
# 	commons-lang#commons-lang;2.6 from central in [default]
# 	graphframes#graphframes;0.8.3-spark3.5-s_2.12 from spark-packages in [default]
# 	net.postgis#postgis-geometry;2021.1.0 from central in [default]
# 	net.postgis#postgis-jdbc;2021.1.0 from central in [default]
# 	net.sf.geographiclib#GeographicLib-Java;1.52 from central in [default]
# 	org.apache.commons#commons-math3;3.6.1 from central in [default]
# 	org.apache.sedona#sedona-common;1.7.0 from central in [default]
# 	org.apache.sedona#sedona-spark-3.5_2.12;1.7.0 from central in [default]
# 	org.apache.sedona#sedona-spark-common-3.5_2.12;1.7.0 from central in [default]
# 	org.beryx#awt-color-factory;1.0.0 from central in [default]
# 	org.checkerframework#checker-qual;3.10.0 from central in [default]
# 	org.codehaus.mojo#animal-sniffer-annotations;1.14 from central in [default]
# 	org.datasyslab#geotools-wrapper;1.7.0-28.5 from central in [default]
# 	org.locationtech.jts#jts-core;1.20.0 from central in [default]
# 	org.locationtech.spatial4j#spatial4j;0.8 from central in [default]
# 	org.postgresql#postgresql;42.5.4 from central in [default]
# 	org.scala-lang.modules#scala-collection-compat_2.12;2.5.0 from central in [default]
# 	org.slf4j#slf4j-api;1.7.36 from central in [default]
# 	org.wololo#jts2geojson;0.16.1 from central in [default]
# 	org.xerial#sqlite-jdbc;3.41.2.2 from central in [default]
# 	:: evicted modules:
# 	org.checkerframework#checker-qual;2.0.0 by [org.checkerframework#checker-qual;3.10.0] in [default]
# 	com.google.errorprone#error_prone_annotations;2.1.3 by [com.google.errorprone#error_prone_annotations;2.5.1] in [default]
# 	org.slf4j#slf4j-api;1.7.32 by [org.slf4j#slf4j-api;1.7.36] in [default]
# 	org.postgresql#postgresql;42.2.23 by [org.postgresql#postgresql;42.5.4] in [default]
# 	org.checkerframework#checker-qual;3.5.0 by [org.checkerframework#checker-qual;3.10.0] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   32  |   0   |   0   |   5   ||   27  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-ca804951-816e-4851-b0a0-20634a08ab36
# 	confs: [default]
# 	0 artifacts copied, 27 already retrieved (0kB/10ms)
# 24/12/11 09:43:52 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/12/11 09:43:53 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/12/11 09:43:53 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %%
boundaries_sdf = sedona.createDataFrame(imd_lsoa_bua_gdf.drop(columns=['LSOA21NMW', 'LAD22NMW', 'BUA22NMG', 'BUA22NMW', 'RGN22NMW'], axis=1))
boundaries_sdf.createOrReplaceTempView('boundaries')
imd_england_sdf = sedona.createDataFrame(imd_england_gdf)
imd_england_sdf.createOrReplaceTempView('imd_england')
buildings_sdf = sedona.read.format("geoparquet").load(str(buildings_path))
buildings_sdf.createOrReplaceTempView("buildings")

# %%
t3_sdf = sedona.read.csv(str(T3_dir), header=True, inferSchema=True)
t3_sdf.createOrReplaceTempView("t3")
t30_sdf = sedona.read.csv(str(T30_dir), header=True, inferSchema=True)
t30_sdf.createOrReplaceTempView("t30")
t300_sdf = sedona.read.csv(str(T300_dir), header=True, inferSchema=True)
t300_sdf.createOrReplaceTempView("t300")

# %%
# Perform spatial join
buildings_lsoa_sdf = sedona.sql(
    """
    SELECT b.*, l.LSOA11CD
    FROM buildings b
    JOIN boundaries l
    ON ST_Contains(l.geometry, b.geometry)
    """
)
buildings_lsoa_sdf.createOrReplaceTempView("buildings")

# %%
buildings_sdf.groupBy("map_use").count().orderBy("count", ascending=False).show()
# Out:
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# 24/12/10 11:05:57 WARN GeoParquetFileFormat: GeoParquet currently does not support vectorized reader. Falling back to parquet-mr
# +--------------------+--------+
# |             map_use|   count|
# +--------------------+--------+
# |         Residential|24697879|
# |             Unknown| 1141942|
# |        Agricultural|  828528|
# |Commercial - mixe...|  798021|
# |Recreation and le...|  297022|
# |Retail below offi...|  247084|
# |            Industry|  184183|
# |              Retail|  175795|
# |         Educational|  167665|
# |              Office|   72740|
# |           Religious|   67110|
# |Institutional acc...|   43958|
# |           Utilities|   37985|
# |           Transport|   35858|
# |              Health|   35365|
# |        Unclassified|   24669|
# |         Complex use|   15604|
# |        Governmental|   14061|
# |Residential with ...|   11000|
# |Commercial - dere...|   10424|
# +--------------------+--------+
# only showing top 20 rows

# %%
t30_imd_lsoa_sdf = sedona.sql(
    """
    SELECT b.*, ROUND(ST_Area(b.geometry), 2) AS area, i.*, t.canopy_cover
    FROM boundaries b
    LEFT JOIN imd_england i ON b.LSOA11CD = i.lsoa11cd
    LEFT JOIN t30 t ON b.LSOA11CD = t.LSOA11CD
    """
)
t30_imd_lsoa_sdf.createOrReplaceTempView("t30_imd_lsoa")
t30_imd_lsoa_sdf.show()
# Out:
# +---------+--------------------+---------+--------------------+---------+--------------------+---------+--------------------+---------+-------+--------------------+---------+------+------+--------+------+-------+--------+----------+--------+--------+-------+------+--------+-------+------+--------+-------+------+--------+-------+------+--------+-------+------+--------+-------+------+--------+-------+------+------------+
# | LSOA11CD|            LSOA11NM| LSOA21CD|            LSOA21NM|  LAD22CD|             LAD22NM|  BUA22CD|             BUA22NM|  RGN22CD|RGN22NM|            geometry| lsoa11cd|TotPop|DepChi|Pop16_59|Pop60+|WorkPop|IMD_Rank|IMD_Decile|IMDScore|IncScore|IncRank|IncDec|EmpScore|EmpRank|EmpDec|EduScore|EduRank|EduDec|HDDScore|HDDRank|HDDDec|CriScore|CriRank|CriDec|BHSScore|BHSRank|BHSDec|EnvScore|EnvRank|EnvDec|canopy_cover|
# +---------+--------------------+---------+--------------------+---------+--------------------+---------+--------------------+---------+-------+--------------------+---------+------+------+--------+------+-------+--------+----------+--------+--------+-------+------+--------+-------+------+--------+-------+------+--------+-------+------+--------+-------+------+--------+-------+------+--------+-------+------+------------+
# |E01000008|Barking and Dagen...|E01000008|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|MULTIPOLYGON (((5...|E01000008|  1566|   534|     961|    71|  939.5|    5010|         2|  37.596|   0.265|   3382|     2|   0.151|   6431|     2|  25.506|  10569|     4|    0.25|  12334|     4|   0.353|  11113|     4|  45.413|    981|     1|  30.233|   8672|     3|        3.34|
# |E01000020|Barking and Dagen...|E01000020|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|POLYGON ((547409....|E01000020|  1947|   479|    1185|   283| 1152.5|    5520|         2|  36.035|   0.216|   5760|     2|   0.131|   8401|     3|  24.184|  11245|     4|    0.76|   6282|     2|   0.651|   7066|     3|  43.518|   1319|     1|  30.078|   8756|     3|        3.14|
# |E01000017|Barking and Dagen...|E01000017|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|POLYGON ((549186....|E01000017|  1516|   395|     901|   220|  885.0|    4570|         2|  39.004|    0.25|   4033|     2|   0.169|   5016|     2|  22.899|  11972|     4|   0.694|   6950|     3|   0.317|  11685|     4|  45.929|    902|     1|  27.688|  10141|     4|        1.98|
# |E01000005| City of London 001E|E01000005| City of London 001E|E09000001|      City of London|E63004906|City and County o...|E12000007| London|POLYGON ((533807....|E01000005|  1121|   229|     692|   200|  683.0|    8678|         3|  28.652|   0.211|   6029|     2|   0.136|   7833|     3|   22.26|  12370|     4|  -0.121|  17907|     6|  -1.317|  31059|    10|    39.9|   2217|     1|  28.979|   9397|     3|        0.74|
# |E01000003| City of London 001C|E01000003| City of London 001C|E09000001|      City of London|E63004906|City and County o...|E12000007| London|POLYGON ((532135....|E01000003|  1350|   146|     759|   445|  804.0|   14915|         5|  19.402|   0.086|  18510|     6|   0.086|  15103|     5|   5.804|  26386|     9|  -0.102|  17600|     6|  -1.032|  29363|     9|  40.103|   2157|     1|  40.535|   4092|     2|        2.26|
# |E01000006|Barking and Dagen...|E01000006|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|POLYGON ((545122....|E01000006|  2040|   522|    1297|   221| 1284.5|   14486|         5|  19.837|   0.117|  14023|     5|   0.059|  21692|     7|  14.798|  17511|     6|  -0.359|  21581|     7|  -0.147|  18848|     6|  45.171|   1033|     1|  26.888|  10629|     4|        2.06|
# |E01000012|Barking and Dagen...|E01000012|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|POLYGON ((544240....|E01000012|  2023|   670|    1233|   120|1248.75|    5990|         2|  34.714|   0.239|   4570|     2|   0.096|  13201|     5|  19.774|  13896|     5|  -0.056|  16887|     6|   0.542|   8515|     3|  56.507|     39|     1|  36.881|   5437|     2|        4.41|
# |E01000016|Barking and Dagen...|E01000016|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|POLYGON ((549604 ...|E01000016|  1750|   461|    1064|   225|1036.25|    6739|         3|  32.839|   0.199|   6711|     3|   0.122|   9461|     3|  28.996|   8971|     3|   0.373|  10676|     4|   0.528|   8699|     3|  43.772|   1273|     1|   24.95|  11815|     4|        2.21|
# |E01000021|Barking and Dagen...|E01000021|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|POLYGON ((546855 ...|E01000021|  1682|   441|    1047|   194| 1034.0|    4611|         2|  38.888|    0.23|   5007|     2|   0.136|   7865|     3|  31.637|   7939|     3|   0.418|  10085|     4|   0.559|   8283|     3|  45.544|    961|     1|  44.214|   3095|     1|        3.19|
# |E01000013|Barking and Dagen...|E01000013|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|POLYGON ((549285....|E01000013|  1747|   433|    1038|   276|1035.25|    4573|         2|  38.997|   0.213|   5966|     2|   0.145|   7013|     3|  24.003|  11346|     4|    0.67|   7172|     3|   1.199|   2236|     1|  45.252|   1018|     1|  30.424|   8569|     3|        2.48|
# |E01000001| City of London 001A|E01000001| City of London 001A|E09000001|      City of London|E63004906|City and County o...|E12000007| London|POLYGON ((532105....|E01000001|  1296|   175|     656|   465|  715.0|   29199|         9|   6.208|   0.007|  32831|    10|    0.01|  32742|    10|   0.024|  32842|    10|  -1.654|  32113|    10|  -2.012|  32662|    10|  29.472|   7319|     3|  31.873|   7789|     3|        2.32|
# |E01000002| City of London 001B|E01000002| City of London 001B|E09000001|      City of London|E63004906|City and County o...|E12000007| London|POLYGON ((532746....|E01000002|  1156|   182|     580|   394| 619.75|   30379|        10|   5.143|   0.034|  29901|    10|   0.027|  31190|    10|   0.063|  32832|    10|  -1.115|  29705|    10|  -2.343|  32789|    10|  24.412|  11707|     4|  23.084|  13070|     4|        1.76|
# |E01000022|Barking and Dagen...|E01000022|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|POLYGON ((547136....|E01000022|  1372|   390|     822|   160| 804.75|    6098|         2|  34.413|   0.195|   6941|     3|   0.139|   7576|     3|  27.111|   9771|     3|   0.427|   9980|     4|   0.506|   9002|     3|  44.277|   1191|     1|  30.435|   8559|     3|        2.09|
# |E01000010|Barking and Dagen...|E01034474|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|POLYGON ((544174 ...|E01000010|  3195|   837|    2213|   145| 2234.0|    6900|         3|  32.437|   0.169|   8902|     3|   0.073|  17988|     6|  11.762|  20182|     7|  -0.002|  16050|     5|   1.214|   2164|     1|   50.58|    259|     1|  47.932|   2269|     1|        3.25|
# |E01000014|Barking and Dagen...|E01000014|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|POLYGON ((548804 ...|E01000014|  1669|   401|    1044|   224|1022.25|    5650|         2|   35.67|   0.201|   6627|     3|   0.135|   7932|     3|  31.501|   7994|     3|    0.35|  10972|     4|   0.825|   5163|     2|  46.135|    872|     1|  25.122|  11704|     4|        1.68|
# |E01000019|Barking and Dagen...|E01000019|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|POLYGON ((547052....|E01000019|  1498|   422|     873|   203|  863.0|    6410|         2|   33.62|   0.194|   7049|     3|   0.138|   7641|     3|  26.111|  10264|     4|   0.477|   9374|     3|   0.645|   7142|     3|  41.248|   1855|     1|  26.826|  10667|     4|        2.46|
# |E01000015|Barking and Dagen...|E01000015|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|POLYGON ((549673....|E01000015|  2372|   712|    1440|   220|1402.25|    6405|         2|  33.632|   0.216|   5755|     2|   0.123|   9271|     3|  26.013|  10318|     4|   0.025|  15626|     5|   0.372|  10845|     4|    50.4|    278|     1|  25.696|  11351|     4|        3.24|
# |E01000007|Barking and Dagen...|E01000007|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|POLYGON ((544180....|E01000007|  2101|   572|    1424|   105| 1404.0|    7256|         3|  31.576|   0.207|   6261|     2|   0.107|  11487|     4|  11.385|  20536|     7|  -0.027|  16414|     5|   0.846|   4925|     2|   50.42|    274|     1|  25.995|  11162|     4|        1.84|
# |E01000009|Barking and Dagen...|E01000009|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|POLYGON ((544499....|E01000009|  1775|   356|    1190|   229|1216.75|    6736|         3|  32.844|   0.187|   7506|     3|   0.109|  11132|     4|  15.713|  16819|     6|   0.454|   9661|     3|   0.895|   4431|     2|  48.119|    554|     1|  28.601|   9611|     3|        1.76|
# |E01000018|Barking and Dagen...|E01000018|Barking and Dagen...|E09000002|Barking and Dagenham|E63004859|Barking and Dagenham|E12000007| London|POLYGON ((549333....|E01000018|  1791|   463|    1113|   215| 1079.0|    6504|         2|  33.406|   0.212|   5998|     2|   0.136|   7832|     3|  26.358|  10125|     4|   0.273|  12006|     4|   0.457|   9663|     3|  43.512|   1323|     1|  25.659|  11373|     4|        3.17|
# +---------+--------------------+---------+--------------------+---------+--------------------+---------+--------------------+---------+-------+--------------------+---------+------+------+--------+------+-------+--------+----------+--------+--------+-------+------+--------+-------+------+--------+-------+------+--------+-------+------+--------+-------+------+--------+-------+------+--------+-------+------+------------+
# only showing top 20 rows

# %%
t3_300_building_sdf = sedona.sql(
    """
    SELECT b.*, t3.tree_count, t300.closest_park_access_id, t300.distance
    FROM buildings b
    LEFT JOIN t3 ON b.verisk_premise_id = t3.verisk_premise_id
    LEFT JOIN t300 ON b.verisk_premise_id = t300.verisk_premise_id
    """
)
t3_300_building_sdf.createOrReplaceTempView("t3_300_building")
t3_300_building_sdf.show()
# Out:
# 24/12/10 11:02:52 WARN JoinQuery: UseIndex is true, but no index exists. Will build index on the fly.
# [Stage 73:=====================================================>(273 + 1) / 274]
# +-------------+-----------------+--------------+------+---------------+--------------------+-------------------+--------------------+--------------------+------------+------------------+-----------------+--------------------+---------+----------+----------------------+--------+
# |building_area|distance_building|distance_water|height| map_simple_use|             map_use|premise_floor_count|        premise_type|         premise_use|premise_year|verisk_building_id|verisk_premise_id|            geometry| LSOA11CD|tree_count|closest_park_access_id|distance|
# +-------------+-----------------+--------------+------+---------------+--------------------+-------------------+--------------------+--------------------+------------+------------------+-----------------+--------------------+---------+----------+----------------------+--------+
# |        394.2|             17.5|          80.8|   7.1|Non Residential|        Agricultural|                  6|                NULL|        Agricultural|        NULL|          29936215|           989871|POLYGON ((470815....|E01016308|      NULL|  AF07C470-25D3-42E...|  7063.0|
# |         30.8|             13.7|         131.2|   3.0|    Residential|         Residential|                  1|Domestic outbuilding|         Residential|        NULL|          41424576|          2703102|POLYGON ((440950....|E01011309|      NULL|  0DFAF531-D395-419...|  4343.0|
# |        208.6|              4.9|          99.9|   5.2|Non Residential|Commercial - mixe...|                  1|                NULL|Commercial - mixe...|        NULL|          28349339|          4277205|POLYGON ((543391....|E01021022|      NULL|  F74987DC-F11F-443...|  9267.0|
# |        181.4|              6.0|         205.8|   9.4|    Residential|         Residential|                  2|            Detached|         Residential|        NULL|          36669694|          4580123|POLYGON ((388870....|E01018395|      NULL|  3F0FF832-33C8-4E4...|  2946.0|
# |       1240.9|              0.0|         881.0|   8.3|    Residential|         Residential|                  2|       Semi-detached|         Residential|        NULL|          37357081|         12679307|POLYGON ((432036....|E01009522|      NULL|  BBD4E25C-BFC5-4C6...|   361.0|
# |        412.9|              9.6|         765.4|   8.7|    Residential|         Residential|                  2|             Terrace|         Residential|      2013.0|          39855960|         25606121|POLYGON ((386584....|E01005061|      NULL|  6B3E4011-97DD-417...|    83.0|
# |        367.6|              0.0|         108.1|   8.9|    Residential|         Residential|                  2|             Terrace|         Residential|        NULL|          39985434|         26109564|POLYGON ((371102....|E01004766|      NULL|  861FB241-79B2-461...|   588.0|
# |        279.8|              0.0|         384.9|   6.7|    Residential|         Residential|                  2|         End-terrace|         Residential|        NULL|          36929028|         27529992|POLYGON ((398012....|E01009155|      NULL|  14E8D851-0E47-432...|  3064.0|
# |         37.1|              3.2|         616.0|   3.0|    Residential|         Residential|                  1|Domestic outbuilding|         Residential|        NULL|          44317902|         29144216|POLYGON ((449779 ...|E01011949|      NULL|  9E64E114-2F8B-452...|   919.0|
# |         41.2|              2.8|         295.2|   3.0|    Residential|         Residential|                  1|Domestic outbuilding|         Residential|        NULL|          28559740|         30695466|POLYGON ((335168....|E01014770|      NULL|  D71ABC66-D717-437...|   383.0|
# |        259.9|              0.0|         473.7|   7.7|    Residential|         Residential|                  2|       Semi-detached|         Residential|        NULL|          40829200|         36695254|POLYGON ((436918....|E01007317|      NULL|  D015F6F9-5B5E-478...|   914.0|
# |        733.1|              0.0|         526.9|  14.8|Non Residential|         Educational|                  3|                NULL|         Educational|        NULL|          38371018|         38838664|POLYGON ((433697....|E01013453|      NULL|  2827E899-6F79-4F0...|  1451.0|
# |        122.9|              0.0|         532.0|   6.2|    Residential|         Residential|                  2|       Semi-detached|         Residential|        NULL|          38379079|         38908628|POLYGON ((438409....|E01013514|      NULL|  C11B703C-8C64-49A...|  2279.0|
# |        134.4|              0.0|         506.2|   9.2|    Residential|         Residential|                  2|            Detached|         Residential|        NULL|          27792523|         39758260|POLYGON ((466877....|E01017046|      NULL|  445E1EF1-3B8A-4EA...|  1319.0|
# |        153.6|              0.0|         506.5|   8.7|    Residential|         Residential|                  2|       Semi-detached|         Residential|        NULL|          30214705|         40909227|POLYGON ((520181....|E01002915|      NULL|  727B5AE4-1FC2-403...|  1944.0|
# |         28.8|             13.1|           4.3|   3.0|    Residential|         Residential|                  1|Domestic outbuilding|         Residential|        NULL|          33149250|         41138125|POLYGON ((544977....|E01000339|        61|  6A6BBDBC-87AD-4A7...|   242.0|
# |       1868.2|              0.0|         173.5|  10.2|    Residential|         Residential|                  2|         Mid-terrace|         Residential|        NULL|          33512438|         41927595|POLYGON ((540591 ...|E01003543|      NULL|  CC902EA8-0F25-476...|   156.0|
# |        352.6|              0.0|         277.9|   8.6|    Residential|         Residential|                  2|         Mid-terrace|         Residential|      2013.0|          33944051|         42062912|POLYGON ((553731....|E01002276|      NULL|  51A7EE71-62ED-4FF...|   683.0|
# |         96.6|              0.0|         261.5|   8.6|    Residential|         Residential|                  2|       Semi-detached|         Residential|      2013.0|          33944074|         42063409|POLYGON ((553742....|E01002276|      NULL|  51A7EE71-62ED-4FF...|   683.0|
# |        251.2|              0.0|          91.2|  10.9|    Residential|         Residential|                  2|       Semi-detached|         Residential|        NULL|          34106171|         42116807|POLYGON ((537384....|E01001445|      NULL|  3AD38075-0202-476...|   456.0|
# +-------------+-----------------+--------------+------+---------------+--------------------+-------------------+--------------------+--------------------+------------+------------------+-----------------+--------------------+---------+----------+----------------------+--------+
# only showing top 20 rows

# %%
t3_300_building_agg_sdf = sedona.sql(
    """
    SELECT LSOA11CD, ROUND(AVG(tree_count), 2) as tree_count, ROUND(AVG(distance), 2) as park_distance
    FROM t3_300_building
    GROUP BY LSOA11CD
    """
)

# t3_300_building_agg_sdf = sedona.sql("SELECT LSOA11CD, ROUND(tree_count, 2), ROUND(distance, 2) FROM t3_300_building_agg")
t3_300_building_agg_sdf.createOrReplaceTempView("t3_300_building_agg")
t3_300_building_agg_sdf.show()
# Out:
# 24/12/10 11:24:10 WARN JoinQuery: UseIndex is true, but no index exists. Will build index on the fly.
# [Stage 156:====================================================>(197 + 3) / 200]
# +---------+----------+-------------+
# | LSOA11CD|tree_count|park_distance|
# +---------+----------+-------------+
# |E01029873|      NULL|      2141.94|
# |E01026615|      NULL|      1981.59|
# |E01026048|      NULL|     Infinity|
# |E01022207|      NULL|      6844.61|
# |E01023494|      NULL|      3440.36|
# |E01031876|      NULL|      3456.38|
# |E01027281|      NULL|       655.67|
# |E01027633|      NULL|      6460.16|
# |E01027571|      NULL|      4335.07|
# |E01012927|      NULL|      1130.55|
# |E01031630|      NULL|       399.14|
# |E01019498|      NULL|       337.37|
# |E01017869|      NULL|      1743.83|
# |E01012567|      NULL|        472.8|
# |E01031518|      NULL|     Infinity|
# |E01020314|      NULL|     Infinity|
# |E01028794|      NULL|      3429.28|
# |E01019607|      NULL|      3936.35|
# |E01024347|      NULL|      2844.73|
# |E01013256|      NULL|       447.94|
# +---------+----------+-------------+
# only showing top 20 rows
