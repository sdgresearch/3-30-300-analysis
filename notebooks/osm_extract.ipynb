# %%
import osmnx as ox
from pyrosm.data import sources
from pyrosm import OSM, get_data

# %%
fp = get_data('Cambridge')
osm = OSM(fp)
buildings = osm.get_buildings()
buildings.plot()
# Out:
# Downloaded Protobuf data 'Cambridge.osm.pbf' (7.0 MB) to:
# '/var/folders/gr/150_8wbn02s9rdqqvb4pbblh0000gn/T/pyrosm/Cambridge.osm.pbf'
# <Axes: >

# %%
# buildings.info()
buildings['building'].unique()
# Out:
# array(['yes', 'retail', 'commercial', 'civic', 'parking', 'terrace',
#        'apartments', 'house', 'warehouse', 'university', 'supermarket',
#        'public', 'train_station', 'school', 'chapel', 'manor_house',
#        'hospital', 'office', 'pavilion', 'historic', 'barn',
#        'farm_auxiliary', 'church', 'roof', 'residential', 'college',
#        'detached', 'stables', 'industrial', 'shed', 'hall', 'motel',
#        'clubhouse', 'hotel', 'community_centre', 'construction', 'pub',
#        'farmhouse', 'museum', 'fixme', 'greenhouse', 'semidetached_house',
#        'garage', 'sports_centre', 'dormitory', 'garages', 'kindergarten',
#        'bungalow', 'hut', 'collapsed', 'S', 'amenity', 'factory',
#        'hostel', 'service', 'social_facility', 'plant', 'disused',
#        'glasshouse', 'church_hall', 'toilets', 'veterinary', 'cabin',
#        'manufacture', 'farm', 'military', 'grandstand', 'ruins', 'club',
#        'storage_tank', 'kiosk', 'carport', 'mosque', 'seat',
# ...

# %%
sources.cities.cambridge
# Out:
# {'name': 'Cambridge.osm.pbf',
#  'url': 'https://download.bbbike.org/osm/bbbike/Cambridge/Cambridge.osm.pbf'}
