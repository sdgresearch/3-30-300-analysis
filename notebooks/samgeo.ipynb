# %%
import leafmap
from samgeo import tms_to_geotiff
from samgeo.text_sam import LangSAM

# %%
m = leafmap.Map(center=[-22.17615, -51.253043], zoom=18, height="800px")
m.add_basemap("SATELLITE", )

# %%
bbox = m.user_roi_bounds()
if bbox is None:
    bbox = [-51.2565, -22.1777, -51.2512, -22.175]

# %%
image = "Image.tif"
tms_to_geotiff(output=image, bbox=bbox, zoom=19, source="Satellite", overwrite=True)
# Out:
# Downloaded image 01/45
# Downloaded image 02/45
# Downloaded image 03/45
# Downloaded image 04/45
# Downloaded image 05/45
# Downloaded image 06/45
# Downloaded image 07/45
# Downloaded image 08/45
# Downloaded image 09/45
# Downloaded image 10/45
# Downloaded image 11/45
# Downloaded image 12/45
# Downloaded image 13/45
# Downloaded image 14/45
# Downloaded image 15/45
# Downloaded image 16/45
# Downloaded image 17/45
# Downloaded image 18/45
# Downloaded image 19/45
# Downloaded image 20/45
# Downloaded image 21/45
# Downloaded image 22/45
# Downloaded image 23/45
# Downloaded image 24/45
# Downloaded image 25/45
# Downloaded image 26/45
# Downloaded image 27/45
# Downloaded image 28/45
# Downloaded image 29/45
# Downloaded image 30/45
# Downloaded image 31/45
# Downloaded image 32/45
# Downloaded image 33/45
# Downloaded image 34/45
# Downloaded image 35/45
# Downloaded image 36/45
# Downloaded image 37/45
# Downloaded image 38/45
# Downloaded image 39/45
# Downloaded image 40/45
# Downloaded image 41/45
# Downloaded image 42/45
# Downloaded image 43/45
# Downloaded image 44/45
# Downloaded image 45/45
# Saving GeoTIFF. Please wait...
# Image saved to Image.tif

# %%
m.layers[-1].visible = False
m.add_raster(image, layer_name="Image")
m
# Out:
# Map(bottom=9506.0, center=[-19.68397023588844, -45.70312500000001], controls=(ZoomControl(options=['position',…

# %%
sam = LangSAM()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 sam = LangSAM()
#
# File ~/Documents/PhD_Thesis/Tree_detection/.venv/lib/python3.12/site-packages/samgeo/text_sam.py:121, in LangSAM.__init__(self, model_type, checkpoint)
#     113 """Initialize the LangSAM instance.
#     114
#     115 Args:
#     116     model_type (str, optional): The model type. It can be one of the following: vit_h, vit_l, vit_b.
#     117         Defaults to 'vit_h'. See https://bit.ly/3VrpxUh for more details.
#     118 """
#     120 self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# --> 121 self.build_groundingdino()
#     122 self.build_sam(model_type, checkpoint)
#     124 self.source = None
#
# File ~/Documents/PhD_Thesis/Tree_detection/.venv/lib/python3.12/site-packages/samgeo/text_sam.py:155, in LangSAM.build_groundingdino(self)
#     153 ckpt_filename = "groundingdino_swinb_cogcoor.pth"
#     154 ckpt_config_filename = "GroundingDINO_SwinB.cfg.py"
# --> 155 self.groundingdino = load_model_hf(
#     156     ckpt_repo_id, ckpt_filename, ckpt_config_filename, self.device
#     157 )
#
# File ~/Documents/PhD_Thesis/Tree_detection/.venv/lib/python3.12/site-packages/samgeo/text_sam.py:73, in load_model_hf(repo_id, filename, ckpt_config_filename, device)
#      55 """
#      56 Loads a model from HuggingFace Model Hub.
#      57
#    (...)
#      65     torch.nn.Module: The loaded model.
#      66 """
#      68 cache_config_file = hf_hub_download(
#      69     repo_id=repo_id,
#      70     filename=ckpt_config_filename,
#      71     force_filename=ckpt_config_filename,
#      72 )
# ---> 73 args = SLConfig.fromfile(cache_config_file)
#      74 model = build_model(args)
#      75 model.to(device)
#
# NameError: name 'SLConfig' is not defined
